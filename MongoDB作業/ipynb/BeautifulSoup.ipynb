# %%
import requests
from bs4 import BeautifulSoup

# %%
mes = "早安圖"

# %%
url = "https://www.google.com/search?q=" + mes + "&source=lnms&tbm=isch&sa=X&ved=2ahUKEwi7jrODs5ryAhVPCqYKHX-HCxsQ_AUoAXoECAEQAw&biw=625&bih=926"
url
# Out:
# 'https://www.google.com/search?q=早安圖&source=lnms&tbm=isch&sa=X&ved=2ahUKEwi7jrODs5ryAhVPCqYKHX-HCxsQ_AUoAXoECAEQAw&biw=625&bih=926'

# %%
url = "https://www.google.com/search?q=%E6%97%A9%E5%AE%89%E5%9C%96&tbm=isch"
url
# Out:
# 'https://www.google.com/search?q=%E6%97%A9%E5%AE%89%E5%9C%96&tbm=isch'

# %%
response = requests.get(url)
# soup = BeautifulSoup(response.text, 'html.parser')



#建立爬取對象
soup = BeautifulSoup(response.text, 'lxml')
#解析器：lxml(官方推薦，速度最快)

# %%
url
# Out:
# 'https://www.google.com/search?q=%E6%97%A9%E5%AE%89%E5%9C%96&tbm=isch'

# %%
soup
# Out:
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# <html lang="zh-TW" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="application/xhtml+xml; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="no-cache" name="Cache-Control"/>
#   <title>
#    早安圖 - Google 搜尋
#   </title>
#   <style>
# ...

# %%
# https://www.google.com/search?q=%E6%97%A9%E5%AE%89%E5%9C%96&tbm=isch

# %%
selects = soup.select("img.yWs4tf")
# selects  = soup.select("a")

# %%
selects
# Out:
# [<img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ-CxbW4LbnxSFYxsYN1000F8iD8pdd6626y28IMFyybs541XqI2K3WVnHBmw&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQUdBNvteH7LicX4J0xumYaVyS9-oQIYShaEUQE_aOlpthT67ZXpU7m0TyFcjA&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTlpbTtJ4OPv7cnIyPslV41uln7nTHaod9QdM7_cBAlAwvK8vg7cCMDH7svd-k&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSRICjnvNthzEIfWmbVZ6QCnP04VFh0voZJf_6WS6dHf6GUfA1ttyMK0XbW7kc&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQKyeXrlzqxLf6eZGASoZ0o_HyZLijEpC0Ra0rWMkCwg4Q9CPBkMiQ7djedhg&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRrMT5jlqOFS2Ghp2etNrSPRk4xIqVGYvaN9nyT4ng7WUv_uN1HU-tZaxcTTg&amp;s"/>,
# ...

# %%
for select in selects:
    print(select['src'])
# Out:
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQ-CxbW4LbnxSFYxsYN1000F8iD8pdd6626y28IMFyybs541XqI2K3WVnHBmw&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQUdBNvteH7LicX4J0xumYaVyS9-oQIYShaEUQE_aOlpthT67ZXpU7m0TyFcjA&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTlpbTtJ4OPv7cnIyPslV41uln7nTHaod9QdM7_cBAlAwvK8vg7cCMDH7svd-k&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSRICjnvNthzEIfWmbVZ6QCnP04VFh0voZJf_6WS6dHf6GUfA1ttyMK0XbW7kc&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQKyeXrlzqxLf6eZGASoZ0o_HyZLijEpC0Ra0rWMkCwg4Q9CPBkMiQ7djedhg&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRrMT5jlqOFS2Ghp2etNrSPRk4xIqVGYvaN9nyT4ng7WUv_uN1HU-tZaxcTTg&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTsjEQVqdcCgpT2X_ZyYa1_Bi_FXACLXLhNts2kryiYzYDfQMYxxxbH6_cYsA&s
# https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSB8jMr5-MV-4mLaQ_Gma9GjNvb-Hio5sh-eULJ1f1PIyCHK_CY3DlZAuQdRME&s
# ...

# %%
pip install mechanize
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install urlparse
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement urlparse (from versions: none)
# ERROR: No matching distribution found for urlparse

# %%
import urllib
import mechanize
from bs4 import BeautifulSoup 
# from urlparse import urlparse
from urllib.parse import urlparse

def getPic(search):
    try:
        browser = mechanize.Browser()
        browser.set_handle_robots(False)
        browser.addheaders = [('User-agent','Mozilla')]

#         htmltext = browser.open("https://www.google.co.kr/search?site=&tbm=isch&source=hp&biw=1204&bih=673&q=cars&oq=cars&gws_rd=cr&ei=Z6XrWOryEMia8QX7x5aYCg")
        htmltext = browser.open("https://www.google.com/search?q=%E6%97%A9%E5%AE%89%E5%9C%96&tbm=isch")
        img_urls = []
        formatted_images = []
        soup = BeautifulSoup(htmltext, "html.parser")
        results = soup.findAll("a")

        print(results)

    except:
        print("error")


getPic("occupy wall street")
# Out:
# [<a class="lXLRf" href="/?output=images&amp;ie=UTF-8&amp;tbm=isch&amp;sa=X&amp;ved=0ahUKEwje5oKxzrH0AhWpG6YKHchGCTEQPAgC"><img alt="Google" class="kgJEQe" src="/images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif"/></a>, <a class="CsQyDc" href="/search?q=%E6%97%A9%E5%AE%89%E5%9C%96&amp;ie=UTF-8&amp;source=lnms&amp;sa=X&amp;ved=0ahUKEwje5oKxzrH0AhWpG6YKHchGCTEQ_AUIBCgA">全部</a>, <a class="CsQyDc" href="/search?q=%E6%97%A9%E5%AE%89%E5%9C%96&amp;ie=UTF-8&amp;tbm=vid&amp;source=lnms&amp;sa=X&amp;ved=0ahUKEwje5oKxzrH0AhWpG6YKHchGCTEQ_AUIBigC">影片</a>, <a class="CsQyDc" href="/search?q=%E6%97%A9%E5%AE%89%E5%9C%96&amp;ie=UTF-8&amp;tbm=nws&amp;source=lnms&amp;sa=X&amp;ved=0ahUKEwje5oKxzrH0AhWpG6YKHchGCTEQ_AUIBygD">新聞</a>, <a class="TwVfHd" href="/search?ie=UTF-8&amp;tbm=isch&amp;q=%E6%97%A9%E5%AE%89%E5%9C%96&amp;chips=q:%E6%97%A9+%E5%AE%89+%E5%9C%96,online_chips:2021&amp;sa=X&amp;ved=0ahUKEwje5oKxzrH0AhWpG6YKHchGCTEQ4lYICygA">2021</a>, <a class="TwVfHd" href="/search?ie=U
# ...

# %%
import requests, lxml, re, json, urllib.request
from bs4 import BeautifulSoup


headers = {
    "User-Agent":
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36 Edge/18.19582"
}

params = {
#     "q": "pexels cat",
    "q": "pexels 早安圖",
    "tbm": "isch", 
    "hl": "en",
    "ijn": "0",
}

html = requests.get("https://www.google.com/search", params=params, headers=headers)
soup = BeautifulSoup(html.text, 'lxml')


def get_images_data():

    print('\nGoogle Images Metadata:')
    for google_image in soup.select('.isv-r.PNCib.MSM1fd.BUooTd'):
        title = google_image.select_one('.VFACy.kGQAp.sMi44c.lNHeqe.WGvvNb')['title']
        source = google_image.select_one('.fxgdke').text
        link = google_image.select_one('.VFACy.kGQAp.sMi44c.lNHeqe.WGvvNb')['href']
        print(f'{title}\n{source}\n{link}\n')

    # this steps could be refactored to a more compact
    all_script_tags = soup.select('script')

    # # https://regex101.com/r/48UZhY/4
    matched_images_data = ''.join(re.findall(r"AF_initDataCallback\(([^<]+)\);", str(all_script_tags)))
    
    # https://kodlogs.com/34776/json-decoder-jsondecodeerror-expecting-property-name-enclosed-in-double-quotes
    # if you try to json.loads() without json.dumps it will throw an error:
    # "Expecting property name enclosed in double quotes"
    matched_images_data_fix = json.dumps(matched_images_data)
    matched_images_data_json = json.loads(matched_images_data_fix)

    # https://regex101.com/r/pdZOnW/3
    matched_google_image_data = re.findall(r'\[\"GRID_STATE0\",null,\[\[1,\[0,\".*?\",(.*),\"All\",', matched_images_data_json)

    # https://regex101.com/r/NnRg27/1
    matched_google_images_thumbnails = ', '.join(
        re.findall(r'\[\"(https\:\/\/encrypted-tbn0\.gstatic\.com\/images\?.*?)\",\d+,\d+\]',
                   str(matched_google_image_data))).split(', ')

    print('Google Image Thumbnails:')  # in order
    for fixed_google_image_thumbnail in matched_google_images_thumbnails:
        # https://stackoverflow.com/a/4004439/15164646 comment by Frédéric Hamidi
        google_image_thumbnail_not_fixed = bytes(fixed_google_image_thumbnail, 'ascii').decode('unicode-escape')

        # after first decoding, Unicode characters are still present. After the second iteration, they were decoded.
        google_image_thumbnail = bytes(google_image_thumbnail_not_fixed, 'ascii').decode('unicode-escape')
        print(google_image_thumbnail)

    # removing previously matched thumbnails for easier full resolution image matches.
    removed_matched_google_images_thumbnails = re.sub(
        r'\[\"(https\:\/\/encrypted-tbn0\.gstatic\.com\/images\?.*?)\",\d+,\d+\]', '', str(matched_google_image_data))

    # https://regex101.com/r/fXjfb1/4
    # https://stackoverflow.com/a/19821774/15164646
    matched_google_full_resolution_images = re.findall(r"(?:'|,),\[\"(https:|http.*?)\",\d+,\d+\]",
                                                       removed_matched_google_images_thumbnails)


    print('\nDownloading Google Full Resolution Images:')  # in order
    for index, fixed_full_res_image in enumerate(matched_google_full_resolution_images):
        # https://stackoverflow.com/a/4004439/15164646 comment by Frédéric Hamidi
        original_size_img_not_fixed = bytes(fixed_full_res_image, 'ascii').decode('unicode-escape')
        original_size_img = bytes(original_size_img_not_fixed, 'ascii').decode('unicode-escape')
        print(original_size_img)

        # ------------------------------------------------
        # Download original images

        # print(f'Downloading {index} image...')
        
        opener=urllib.request.build_opener()
        opener.addheaders=[('User-Agent','Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36 Edge/18.19582')]
        urllib.request.install_opener(opener)

        urllib.request.urlretrieve(original_size_img, f'Images/original_size_img_{index}.jpg')


get_images_data()
# Out:
# Google Images Metadata:
# 早安卡，筆和蛋白杏仁餅乾旁邊裝滿茶碟的茶杯· 免費圖庫相片
# pexels.com
# https://www.pexels.com/zh-tw/photo/2072152/
#
# 90,000+ 張最佳早安相片· 100% 免費下載· Pexels 圖庫相片
# pexels.com
# https://www.pexels.com/zh-tw/search/%E6%97%A9%E5%AE%89/
#
# 早安一聲問候祝天天開心Photo: pexels - 壹陸零人生160cm's Life | Facebook
# facebook.com
# https://www.facebook.com/112013177201434/posts/%E6%97%A9%E5%AE%89%E4%B8%80%E8%81%B2%E5%95%8F%E5%80%99%E7%A5%9D%E5%A4%A9%E5%A4%A9%E9%96%8B%E5%BF%83photo-pexels/135160181553400/
#
# 早安Photo:pexels - 壹陸零人生160cm's Life | Facebook
# m.facebook.com
# https://m.facebook.com/112013177201434/posts/176933110709440/
#
# 有关早, 早上好, 早安的免费素材图片
# pexels.com
# https://www.pexels.com/zh-cn/photo/806473/
#
# 10,000+ 部最佳早安影片· 100% 免費下載· Pexels 圖庫影片
# pexels.com
# https://www.pexels.com/zh-tw/search/videos/%E6%97%A9%E5%AE%89/
#
# 早安日日是好日Photo:pexels - 質感早安圖Textured Morning Pictures | Facebook
# m.facebook.com
# https://m.facebook.com/112013177201434/posts/164225208646897/
#
# ...

# %%
pip install google-search-results
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for google-search-results: filename=google_search_results-2.4.0-py3-none-any.whl size=19876 sha256=3449dd24171369ad1440c6c46302fd150fcfbb065f12c7301ff9f654eecb9667
#   Stored in directory: c:\users\a9025\appdata\local\pip\cache\wheels\93\32\5f\313cc6b6c013f9c6386fc0a75d10b6b1aa7fe6867acc704d41
# Successfully built google-search-results
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from serpapi import GoogleSearch

params = {
  "api_key": "9b09fcfb743f4dcf7a0f7214f6801abd46eb82f07ac3b2167e898adf7236a639",
  "engine": "google",
  "q": "inception",
  "tbm": "isch"
}

search = GoogleSearch(params)
results = search.get_dict()

# %%
results
# Out:
# {'search_metadata': {'id': '619e87b52e7d6ba8b0786013',
#   'status': 'Success',
#   'json_endpoint': 'https://serpapi.com/searches/5798b379beaf4112/619e87b52e7d6ba8b0786013.json',
#   'created_at': '2021-11-24 18:43:01 UTC',
#   'processed_at': '2021-11-24 18:43:01 UTC',
#   'google_url': 'https://www.google.com/search?q=inception&oq=inception&tbm=isch&sourceid=chrome&ie=UTF-8',
#   'raw_html_file': 'https://serpapi.com/searches/5798b379beaf4112/619e87b52e7d6ba8b0786013.html',
#   'total_time_taken': 1.11},
#  'search_parameters': {'engine': 'google',
#   'q': 'inception',
#   'google_domain': 'google.com',
#   'device': 'desktop',
#   'tbm': 'isch'},
#  'search_information': {'image_results_state': 'Results for exact spelling',
#   'query_displayed': 'inception'},
#  'suggested_searches': [{'name': 'wallpaper',
# ...

# %%
import os, urllib.request, json # json for pretty output
from serpapi import GoogleSearch


def get_google_images():
    params = {
      "api_key": "9b09fcfb743f4dcf7a0f7214f6801abd46eb82f07ac3b2167e898adf7236a639",
      "engine": "google",
      "q": "早安圖",
      "tbm": "isch"
    }

    search = GoogleSearch(params)
    results = search.get_dict()

    print(json.dumps(results['images_results'], indent=2, ensure_ascii=False))

    # -----------------------
    # Downloading images

    for index, image in enumerate(results['images_results']):

        # print(f'Downloading {index} image...')
        
        opener=urllib.request.build_opener()
        opener.addheaders=[('User-Agent','Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36 Edge/18.19582')]
        urllib.request.install_opener(opener)

        urllib.request.urlretrieve(image['original'], f'SerpApi_Images/original_size_img_{index}.jpg')


get_google_images()
# Out:
# [
#   {
#     "position": 1,
#     "thumbnail": "https://serpapi.com/searches/619e8863a1b423b36f2c8fbe/images/76aa61c9ce8c379a01aa5de6d424e898e1a685e3ecacc4e57d46a7e36c38443f.jpeg",
#     "source": "pexels.com",
#     "title": "10,000+ Best Cat Photos · 100% Free Download · Pexels Stock Photos",
#     "link": "https://www.pexels.com/search/cat/",
#     "original": "https://images.pexels.com/photos/1170986/pexels-photo-1170986.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500",
#     "is_product": false
#   },
#   {
#     "position": 2,
#     "thumbnail": "https://serpapi.com/searches/619e8863a1b423b36f2c8fbe/images/76aa61c9ce8c379a9f5c2a784c87f87dc122e1347a2085e0a8146535ae271591.jpeg",
#     "source": "pexels.com",
#     "title": "10,000+ Best Cat Photos · 100% Free Download · Pexels Stock Photos",
#     "link": "https://www.pexels.com/search/cat/",
#     "original": "https://images.pexels.com/photos/1543793/pexels-photo-1543793.jpeg?auto=compress&cs=tinysrgb&dpr=1&w=500",
# ...

# %%
import os, urllib.request, json # json for pretty output
from serpapi import GoogleSearch

params = {
  "api_key": "9b09fcfb743f4dcf7a0f7214f6801abd46eb82f07ac3b2167e898adf7236a639",
  "engine": "google",
  "q": "早安圖",
  "tbm": "isch"
}

search = GoogleSearch(params)
results = search.get_dict()

print(json.dumps(results['images_results'], indent=2, ensure_ascii=False))
# Out:
# [
#   {
#     "position": 1,
#     "thumbnail": "https://serpapi.com/searches/619e88a42c6878d5dfd8e8b2/images/b8f1735b30a40259ebec3d94e43357e919a97372f5078d0f17eab8468fd17ab2.jpeg",
#     "source": "pinterest.com",
#     "title": "42 早安圖ideas in 2021",
#     "link": "https://www.pinterest.com/webberbibby/%E6%97%A9%E5%AE%89%E5%9C%96/",
#     "original": "https://i.pinimg.com/originals/f0/b1/14/f0b1141284f30661abed07cc5a8a6706.jpg",
#     "is_product": false
#   },
#   {
#     "position": 2,
#     "thumbnail": "https://serpapi.com/searches/619e88a42c6878d5dfd8e8b2/images/b8f1735b30a4025991ca17dfa9cef00b93aba8fd56f58f2b3a9363d2d333033e.jpeg",
#     "source": "pinterest.com",
#     "title": "900+ 早安語錄ideas in 2021",
#     "link": "https://www.pinterest.com/cubequotestudio/%E6%97%A9%E5%AE%89%E8%AA%9E%E9%8C%84/",
#     "original": "https://i.pinimg.com/736x/0c/f6/3e/0cf63e3a7f1085145fa2306d722f9514.jpg",
#     "is_product": false
#   },
#   {
#     "position": 3,
# ...

# %%
results['images_results']
# Out:
# [{'position': 1,
#   'thumbnail': 'https://serpapi.com/searches/619e88a42c6878d5dfd8e8b2/images/b8f1735b30a40259ebec3d94e43357e919a97372f5078d0f17eab8468fd17ab2.jpeg',
#   'source': 'pinterest.com',
#   'title': '42 早安圖ideas in 2021',
#   'link': 'https://www.pinterest.com/webberbibby/%E6%97%A9%E5%AE%89%E5%9C%96/',
#   'original': 'https://i.pinimg.com/originals/f0/b1/14/f0b1141284f30661abed07cc5a8a6706.jpg',
#   'is_product': False},
#  {'position': 2,
#   'thumbnail': 'https://serpapi.com/searches/619e88a42c6878d5dfd8e8b2/images/b8f1735b30a4025991ca17dfa9cef00b93aba8fd56f58f2b3a9363d2d333033e.jpeg',
#   'source': 'pinterest.com',
#   'title': '900+ 早安語錄ideas in 2021',
#   'link': 'https://www.pinterest.com/cubequotestudio/%E6%97%A9%E5%AE%89%E8%AA%9E%E9%8C%84/',
#   'original': 'https://i.pinimg.com/736x/0c/f6/3e/0cf63e3a7f1085145fa2306d722f9514.jpg',
#   'is_product': False},
#  {'position': 3,
# ...

# %%
for index, image in enumerate(results['images_results']):
    print(image['original'])
# Out:
# https://i.pinimg.com/originals/f0/b1/14/f0b1141284f30661abed07cc5a8a6706.jpg
# https://i.pinimg.com/736x/0c/f6/3e/0cf63e3a7f1085145fa2306d722f9514.jpg
# https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=4159889920726770
# https://i.pinimg.com/550x/2b/36/6e/2b366e09c3244facec3ef143722bf2c3.jpg
# https://s167.daydaynews.cc/?url=http%3A%2F%2Finews.gtimg.com%2Fnewsapp_bt%2F0%2F12904020509%2F1000
# https://i.epochtimes.com/assets/uploads/2018/04/Image_6ec071e.jpg
# https://i04piccdn.sogoucdn.com/23aac9b57bc53607
# https://y.qichejiashi.com/tupian/upload/146477205.jpg
# https://p5.itc.cn/images01/20210822/78168b3d57bd499f9f7f138768ee2189.jpeg
# https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=3924007127648385
# https://i.pinimg.com/originals/d3/cb/58/d3cb580f0605c9522a9f203371c34fb7.jpg
# https://images.apktouch.com/img/h09/h78/img_localize_dd81e177e773dbe1ded0c41489c99753_599x800_480x641.png
# ...

# %%
url      = "https://www.google.com/search?q=" + mes + "&source=lnms&tbm=isch&sa=X&ved=2ahUKEwi7jrODs5ryAhVPCqYKHX-HCxsQ_AUoAXoECAEQAw&biw=625&bih=926"
response = requests.get(url)
soup     = BeautifulSoup(response.text, 'html.parser')
selects  = soup.select("img.yWs4tf")
content  = selects[random.randrange(0, len(selects))]["src"]
